# %% [markdown]
# # Criteo Dataset – Data Viz - Dauphine M2
#
# # Elaboree par CHERIF MONGIA

# %%
# we present first of all the librairies that we need 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exploring data : campaigns_delivery

# %% [markdown]
# #### campaigns_delivery.tsv – Delivery metrics for the online advertising campaigns that the e-commerce website is running with Criteo

# %%
# Read data 
df=pd.read_table(r'C:\Users\monjia\Downloads\campaigns_delivery.tsv',sep='\t')

# %%
#Read the 5 first rows
df.head()
# Out:
#           Day Environment       Os  Campaign ID Campaign Optimization  \
# 0  2019-10-13         app  Android       194439    Visit Optimization
# 1  2019-10-16         web  Windows       194439    Visit Optimization
# 2  2019-11-08         app  Android       194439    Visit Optimization
# 3  2019-10-11         web   Mac OS       194439    Visit Optimization
# 4  2019-10-16         app  Android       194439    Visit Optimization
#
#        Campaign Type Context IDs Eligible  Number of displays  \
# 0  MID FUNNEL CUSTOM               0-6,10               11487
# 1  MID FUNNEL CUSTOM               0-6,10                   0
# 2  MID FUNNEL CUSTOM               0-6,10                   0
# 3  MID FUNNEL CUSTOM               0-6,10                2102
# 4  MID FUNNEL CUSTOM               0-6,10                   0
#
#    Number of clicks  Criteo Revenue  Criteo Cost
# 0               199        1.223468     0.635936
# 1                 0        0.000000     0.000000
# 2                 0        0.000000     0.000000
# 3                21        1.392722     0.842206
# 4                 0        0.000000     0.000000

# %%
#Read the 5 latest rows
df.tail()
# Out:
#              Day Environment       Os  Campaign ID    Campaign Optimization  \
# 8823  2019-11-19         web  Android       194906  Conversion Optimization
# 8824  2019-11-19         web  Windows       194906  Conversion Optimization
# 8825  2019-10-17       other    Other       194906  Conversion Optimization
# 8826  2019-11-14         web      iOS       194906  Conversion Optimization
# 8827  2019-11-15         web      iOS       194906  Conversion Optimization
#
#             Campaign Type Context IDs Eligible  Number of displays  \
# 8823  LOWER FUNNEL CUSTOM                 0-10                   0
# 8824  LOWER FUNNEL CUSTOM                 0-10                   0
# 8825  LOWER FUNNEL CUSTOM                 0-10                   4
# 8826  LOWER FUNNEL CUSTOM                 0-10                   0
# 8827  LOWER FUNNEL CUSTOM                 0-10                   0
#
#       Number of clicks  Criteo Revenue  Criteo Cost
# 8823                 0        0.000000     0.000000
# 8824                 0        0.000000     0.000000
# 8825                 0        0.004939     0.002743
# 8826                 0        0.000000     0.000000
# 8827                 0        0.000000     0.000000

# %%
#The shape and size of dataset 
print('the shape of df:',df.shape)
print('the size of df:',df.size)
# Out:
# the shape of df: (8828, 11)
# the size of df: 97108

# %%
#The columns 
df.columns
# Out:
# Index(['Day', 'Environment', 'Os', 'Campaign ID', 'Campaign Optimization',
#        'Campaign Type', 'Context IDs Eligible', 'Number of displays',
#        'Number of clicks', 'Criteo Revenue', 'Criteo Cost'],
#       dtype='object')

# %%
#print train data columns
print('Columns of the campaigns_delivery dataset is', df.columns)
# Out:
# Columns of the campaigns_delivery dataset is Index(['Day', 'Environment', 'Os', 'Campaign ID', 'Campaign Optimization',
#        'Campaign Type', 'Context IDs Eligible', 'Number of displays',
#        'Number of clicks', 'Criteo Revenue', 'Criteo Cost'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Campaign ID  Number of displays  Number of clicks  Criteo Revenue  \
# count    8828.000000        8.828000e+03       8828.000000     8828.000000
# mean   164273.597191        2.141655e+05       1650.587789      300.494769
# std     36342.317697        5.201823e+05       4037.909541      979.402831
# min    113450.000000        0.000000e+00          0.000000        0.000000
# 25%    113890.000000        2.500000e+01          0.000000        0.030000
# 50%    179971.000000        2.806500e+04        143.000000       24.075285
# 75%    196251.000000        1.604248e+05       1070.000000      168.771213
# max    204638.000000        6.413055e+06      54592.000000    18055.210806
#
#         Criteo Cost
# count   8828.000000
# mean     169.976270
# std      564.852979
# min        0.000000
# 25%        0.019295
# 50%       14.009600
# 75%       92.444600
# max    10587.617563

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8828 entries, 0 to 8827
# Data columns (total 11 columns):
# Day                      8828 non-null object
# Environment              8828 non-null object
# Os                       8828 non-null object
# Campaign ID              8828 non-null int64
# Campaign Optimization    8828 non-null object
# Campaign Type            8828 non-null object
# Context IDs Eligible     8828 non-null object
# Number of displays       8828 non-null int64
# Number of clicks         8828 non-null int64
# Criteo Revenue           8828 non-null float64
# Criteo Cost              8828 non-null float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 758.7+ KB

# %%
#count the nan value for each column 
df.isnull().sum()
# Out:
# Day                      0
# Environment              0
# Os                       0
# Campaign ID              0
# Campaign Optimization    0
# Campaign Type            0
# Context IDs Eligible     0
# Number of displays       0
# Number of clicks         0
# Criteo Revenue           0
# Criteo Cost              0
# dtype: int64

# %% [markdown]
# ## 2.1. Compute the average Criteo margin

# %%
#We add a column for Margin_criteo 
df['Margin_criteo'] = df['Criteo Revenue']-df['Criteo Cost']
df.head()
# Out:
#           Day Environment       Os  Campaign ID Campaign Optimization  \
# 0  2019-10-13         app  Android       194439    Visit Optimization
# 1  2019-10-16         web  Windows       194439    Visit Optimization
# 2  2019-11-08         app  Android       194439    Visit Optimization
# 3  2019-10-11         web   Mac OS       194439    Visit Optimization
# 4  2019-10-16         app  Android       194439    Visit Optimization
#
#        Campaign Type Context IDs Eligible  Number of displays  \
# 0  MID FUNNEL CUSTOM               0-6,10               11487
# 1  MID FUNNEL CUSTOM               0-6,10                   0
# 2  MID FUNNEL CUSTOM               0-6,10                   0
# 3  MID FUNNEL CUSTOM               0-6,10                2102
# 4  MID FUNNEL CUSTOM               0-6,10                   0
#
#    Number of clicks  Criteo Revenue  Criteo Cost  Margin_criteo
# 0               199        1.223468     0.635936       0.587531
# 1                 0        0.000000     0.000000       0.000000
# 2                 0        0.000000     0.000000       0.000000
# 3                21        1.392722     0.842206       0.550516
# 4                 0        0.000000     0.000000       0.000000

# %%
#first method to check the average of the column Margin criteo
# To compute the average Margin_criteo we just write the describe 
df.describe()
#so for the average of Margin_criteo we get 130.518499
# Out:
#          Campaign ID  Number of displays  Number of clicks  Criteo Revenue  \
# count    8828.000000        8.828000e+03       8828.000000     8828.000000
# mean   164273.597191        2.141655e+05       1650.587789      300.494769
# std     36342.317697        5.201823e+05       4037.909541      979.402831
# min    113450.000000        0.000000e+00          0.000000        0.000000
# 25%    113890.000000        2.500000e+01          0.000000        0.030000
# 50%    179971.000000        2.806500e+04        143.000000       24.075285
# 75%    196251.000000        1.604248e+05       1070.000000      168.771213
# max    204638.000000        6.413055e+06      54592.000000    18055.210806
#
#         Criteo Cost  Margin_criteo
# count   8828.000000    8828.000000
# mean     169.976270     130.518499
# std      564.852979     416.195619
# min        0.000000     -75.385498
# 25%        0.019295       0.005985
# 50%       14.009600      10.052453
# 75%       92.444600      72.424785
# max    10587.617563    7467.593244

# %%
# The second methode to check the average 
df['Margin_criteo'].mean()
# Out:
# 130.51849934385925

# %% [markdown]
# ## 2.2. Plot the margin over time (day and then week). Which graph is more insightful? How would you qualify Criteo margin?

# %%
#we first order the Day column
df.sort_values(by=['Day']).head()
# Out:
#              Day Environment       Os  Campaign ID    Campaign Optimization  \
# 4047  2019-10-07         web      iOS       113890  Conversion Optimization
# 6460  2019-10-07         web  Windows       137914  Conversion Optimization
# 8341  2019-10-07         web   Mac OS       179971       Visit Optimization
# 6312  2019-10-07         web      iOS       137914  Conversion Optimization
# 669   2019-10-07         app      iOS       182460       Visit Optimization
#
#             Campaign Type Context IDs Eligible  Number of displays  \
# 4047  LOWER FUNNEL CUSTOM               0-6,10               17630
# 6460  LOWER FUNNEL CUSTOM                 0-10             3959303
# 8341          PROSPECTING               0-6,10                6603
# 6312  LOWER FUNNEL CUSTOM                 0-10              478448
# 669                 INAPP                 2-10              139854
#
#       Number of clicks  Criteo Revenue  Criteo Cost  Margin_criteo
# 4047               121       17.033786     9.788570       7.245215
# 6460             16010     7905.957985  4792.584782    3113.373203
# 8341                10        1.289095     0.884069       0.405026
# 6312              2049      681.591556   405.756166     275.835390
# 669                655       72.308770    39.745127      32.563643

# %%
# By ordering the column day, we show that we have same day appear multiple time so we group by day
#and sum the the Margin criteo per day 
Groupby_Day=df.groupby(['Day'])['Margin_criteo'].sum()
Groupby_Day.head()
# Out:
# Day
# 2019-10-07    8030.812709
# 2019-10-08    3550.634406
# 2019-10-09    4619.908384
# 2019-10-10    7172.925559
# 2019-10-11    6508.447351
# Name: Margin_criteo, dtype: float64

# %%
# the shape become 116,
Groupby_Day.shape
# Out:
# (116,)

# %%
#We plot here the evolution of the Margin_criteo over the day  
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
Groupby_Day.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("Evolution of the margin over the day  " , fontsize = 20)
ax.set_xlabel("Day")
ax.set_ylabel("Amount")
plt.show()

# %% [markdown]
# We visualized the variation of the daily criteo margin, and we were able to identify days when the margin reached these maximums, this behavior for good reason, the days of the holidays (Christmas) and the days of the sales.

# %% [markdown]
# ###### we do a general analysis for the margin criteo
#
# [2019/10/07 - 2019/10/31] the magin criteo approximately between  [5000- 10000]
#
# [2019/11/01 - 2019/11/16] the margin in evolution between [10000-15000]
#
# [2019/11/17 - 2019/12/03] the most interest part where the graph reached the maximum that means represent the days of sales or maybe there are promotions for the end of the year
#
# Then the graph decrease to reach less than 2000 in the end of year and return to the normal case

# %%
# check another view for the graph 
fig, ax = plt.subplots(figsize=(20, 10))
plt.style.use("dark_background")
Groupby_Day.plot()
ax.legend('Margin_criteo')
plt.show()

# %% [markdown]
# To get more details on the peak days we zoom in, our previous explanations are confirmed by this plot, this peak coincides with the Christmas period.

# %%
df['date'] = pd.to_datetime(df['Day'])

# %%
#We count the 'Margin_Criteo ' by month 
Groupby_Month=df.groupby(df['date'].dt.strftime('%B'))['Margin_criteo'].sum().sort_values()
Groupby_Month
# Out:
# date
# October     173900.782808
# December    196329.683308
# January     326570.936044
# November    455415.910048
# Name: Margin_criteo, dtype: float64

# %%
Groupby_Month.shape
# Out:
# (4,)

# %%
#We count the 'Margin_Criteo ' by week 
Groupby_week = df.groupby(pd.Grouper(key='date', freq='1w'))['Margin_criteo'].sum() # groupby each 1 month
Groupby_week.index = Groupby_week.index.strftime('%B')
Groupby_week
# Out:
# October      43589.006068
# October      43431.452893
# October      51336.934737
# November     73970.109082
# November     67783.746074
# November     92503.104001
# November    122716.364956
# December    154578.138384
# December     80128.274951
# December     48695.068910
# December     31361.390754
# December     13367.931904
# January      28491.403962
# January     107157.854273
# January      82243.477033
# January      73286.377216
# February     37576.677009
# Name: Margin_criteo, dtype: float64

# %%
Groupby_week.shape
# Out:
# (17,)

# %%
#We plot here the evolution of the Margin_criteo over the week
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
Groupby_week.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("Evolution of the margin over the time  " , fontsize = 20)
ax.set_xlabel("week")
ax.set_ylabel("Amount")
plt.show()

# %% [markdown]
# We study the variation of criteo margin per month. Criteo reached its peak in December, other remarkable margins reached the months of November and January.global peak in December, other remarkable margins are reached in November and January

# %%
#To check available style
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
# check another view for the graph we use here'fivethirtyeight'  
fig, ax = plt.subplots(figsize=(20, 10))
plt.style.use("fivethirtyeight")
Groupby_week.plot()
ax.legend('Margin_criteo')
plt.show()

# %% [markdown]
# We have on the margin of December November and we have discovered that it is December we reached the maximum margin the first part of the month and the minimum margin the last part of the month

# %% [markdown]
# Note that the graph representing the margin criteo per day is more detailed than the second graph of margin criteo per week. we see here from the two graphs the margin criteo is alternative,is not stable but in general it is not bad

# %% [markdown]
# ## 2.3. Plot the margin by Criteo product. Please comment/investigate the App Install margin.

# %%
#we groupby the compaign Id the sum of margin criteo 
dg=df.groupby(['Campaign ID'])['Margin_criteo'].sum()

# %%
dg
# Out:
# Campaign ID
# 113450    159478.455557
# 113890     39787.781498
# 137914    636310.196889
# 166330         0.000000
# 179971     55337.203695
# 181694       494.256597
# 181696       532.491244
# 182459      3108.481900
# 182460      2933.678806
# 194439      1423.389604
# 194905     15733.850053
# 194906     15914.905969
# 195553         1.085909
# 196137      2728.771397
# 196140      2598.219791
# 196251    115445.440253
# 198525       574.621791
# 200094     96495.489802
# 203944       187.583201
# 203945       120.411894
# 203946       152.612054
# 204638      2858.384303
# Name: Margin_criteo, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
dg.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title(" the margin by Criteo product" , fontsize = 20)
ax.set_xlabel("compaign ID")
ax.set_ylabel("Margin criteo")
plt.legend()
plt.show()

# %% [markdown]
# to plot the margin by criteo product:
#
# the idea here to look for the compaign who allows criteo to have more margin, we found the compaign that had the ID = 137914 it's the most important one and we get more than 600000

# %% [markdown]
# #### Investigate the App install margin

# %%
#Check Campaign Type that have 'APP INSTALL '
APP_INSTALL =df[df['Campaign Type']=='APP INSTALL']

# %%
APP_INSTALL
# Out:
#              Day Environment       Os  Campaign ID Campaign Optimization  \
# 134   2019-10-16         web  Android       181696  Install Optimization
# 135   2019-10-11         web  Unknown       181696  Install Optimization
# 136   2019-10-12         web  Android       181696  Install Optimization
# 137   2019-10-27         web  Android       181696  Install Optimization
# 138   2019-10-23         web      iOS       181696  Install Optimization
# 139   2019-10-23         web    Other       181696  Install Optimization
# 140   2019-10-25         web  Unknown       181696  Install Optimization
# 141   2019-10-08         web      iOS       181696  Install Optimization
# 142   2019-10-12         web  Unknown       181696  Install Optimization
# 143   2019-10-26         web    Other       181696  Install Optimization
# 144   2019-10-21         web      iOS       181696  Install Optimization
# 145   2019-10-14         web      iOS       181696  Install Optimization
# 146   2019-10-17         web      iOS       181696  Install Optimization
# 147   2019-10-11         app  Android       181696  Install Optimization
# 148   2019-11-22         web  Android       181696  Install Optimization
# 149   2019-11-24         app  Android       181696  Install Optimization
# 150   2019-10-29         app  Android       181696  Install Optimization
# 151   2019-10-08         web   Mac OS       181696  Install Optimization
# 152   2019-10-15         web    Other       181696  Install Optimization
# 153   2019-10-28         app  Android       181696  Install Optimization
# 154   2019-10-24         web  Android       181696  Install Optimization
# 155   2019-10-22         web  Windows       181696  Install Optimization
# 156   2019-10-07         web  Android       181696  Install Optimization
# 157   2019-10-10         web  Android       181696  Install Optimization
# 158   2019-10-25         app  Android       181696  Install Optimization
# 159   2019-11-11         app  Android       181696  Install Optimization
# 160   2019-10-10         web    Other       181696  Install Optimization
# 161   2019-10-23         web  Android       181696  Install Optimization
# 162   2019-10-07         web    Other       181696  Install Optimization
# 163   2019-10-18         web  Windows       181696  Install Optimization
# ...          ...         ...      ...          ...                   ...
# 969   2019-10-24         web    Other       181694  Install Optimization
# 970   2019-11-10         app      iOS       181694  Install Optimization
# 971   2019-10-20         app      iOS       181694  Install Optimization
# 972   2019-10-08         app      iOS       181694  Install Optimization
# 973   2019-10-25         web    Other       181694  Install Optimization
# 974   2019-10-28         app      iOS       181694  Install Optimization
# 975   2019-10-16         web  Windows       181694  Install Optimization
# 976   2019-10-14         web      iOS       181694  Install Optimization
# 977   2019-10-25         app      iOS       181694  Install Optimization
# 978   2019-10-31         app      iOS       181694  Install Optimization
# 979   2019-10-12         app      iOS       181694  Install Optimization
# 980   2019-10-11         web    Other       181694  Install Optimization
# 981   2019-10-16         web    Other       181694  Install Optimization
# 982   2019-11-01         app      iOS       181694  Install Optimization
# 983   2019-10-18         web      iOS       181694  Install Optimization
# 984   2019-10-21         web    Other       181694  Install Optimization
# 985   2019-10-12         web   Mac OS       181694  Install Optimization
# 986   2019-10-15         web    Other       181694  Install Optimization
# 987   2019-10-10         web    Other       181694  Install Optimization
# 988   2019-10-17         web  Unknown       181694  Install Optimization
# 989   2019-10-18         web  Windows       181694  Install Optimization
# 990   2019-11-22         app      iOS       181694  Install Optimization
# 991   2019-10-26         web    Other       181694  Install Optimization
# 996   2019-10-07         web      iOS       181694  Install Optimization
# 997   2019-10-07         app      iOS       181694  Install Optimization
# 998   2019-10-08         web  Android       181694  Install Optimization
# 1007  2019-10-12         web      iOS       181694  Install Optimization
# 1008  2019-10-08         web   Mac OS       181694  Install Optimization
# 1009  2019-10-26         app      iOS       181694  Install Optimization
# 1010  2019-10-07         web  Windows       181694  Install Optimization
#
#      Campaign Type Context IDs Eligible  Number of displays  Number of clicks  \
# 134    APP INSTALL                 2-10               18546               295
# 135    APP INSTALL                 2-10                  58                 1
# 136    APP INSTALL                 2-10               20884               337
# 137    APP INSTALL                 2-10               18835               291
# 138    APP INSTALL                 2-10                   7                 0
# 139    APP INSTALL                 2-10                  58                 0
# 140    APP INSTALL                 2-10                   1                 2
# 141    APP INSTALL                 2-10                   9                 0
# 142    APP INSTALL                 2-10                   1                 1
# 143    APP INSTALL                 2-10                  45                 0
# 144    APP INSTALL                 2-10                   2                 0
# 145    APP INSTALL                 2-10                   1                 0
# 146    APP INSTALL                 2-10                   3                 2
# 147    APP INSTALL                 2-10               64380               589
# 148    APP INSTALL                 2-10                   0                 2
# 149    APP INSTALL                 2-10                   0                 0
# 150    APP INSTALL                 2-10                   2                 0
# 151    APP INSTALL                 2-10                   2                 0
# 152    APP INSTALL                 2-10                  27                 0
# 153    APP INSTALL                 2-10               10211               143
# 154    APP INSTALL                 2-10               16426               267
# 155    APP INSTALL                 2-10                   2                 0
# 156    APP INSTALL                 2-10               22401               315
# 157    APP INSTALL                 2-10               11638               208
# 158    APP INSTALL                 2-10               49293               581
# 159    APP INSTALL                 2-10                   0                 0
# 160    APP INSTALL                 2-10                  11                 0
# 161    APP INSTALL                 2-10               19228               334
# 162    APP INSTALL                 2-10                  73                 0
# 163    APP INSTALL                 2-10                   1                 0
# ...            ...                  ...                 ...               ...
# 969    APP INSTALL                 2-10                   8                 0
# 970    APP INSTALL                 2-10                   0                 0
# 971    APP INSTALL                 2-10              100509               371
# 972    APP INSTALL                 2-10               85028               252
# 973    APP INSTALL                 2-10                   3                 0
# 974    APP INSTALL                 2-10               23100               123
# 975    APP INSTALL                 2-10                   1                 0
# 976    APP INSTALL                 2-10                2782                31
# 977    APP INSTALL                 2-10               91300               460
# 978    APP INSTALL                 2-10                   0                 0
# 979    APP INSTALL                 2-10              140274               524
# 980    APP INSTALL                 2-10                   3                 0
# 981    APP INSTALL                 2-10                   8                 0
# 982    APP INSTALL                 2-10                   0                 0
# 983    APP INSTALL                 2-10                3021                41
# 984    APP INSTALL                 2-10                   2                 0
# 985    APP INSTALL                 2-10                   1                 0
# 986    APP INSTALL                 2-10                   5                 0
# 987    APP INSTALL                 2-10                   3                 0
# 988    APP INSTALL                 2-10                   1                 0
# 989    APP INSTALL                 2-10                   2                 0
# 990    APP INSTALL                 2-10                   0                 0
# 991    APP INSTALL                 2-10                   1                 0
# 996    APP INSTALL                 2-10                5333                52
# 997    APP INSTALL                 2-10              153114               409
# 998    APP INSTALL                 2-10                   1                 0
# 1007   APP INSTALL                 2-10                4570                53
# 1008   APP INSTALL                 2-10                   6                 0
# 1009   APP INSTALL                 2-10               77498               419
# 1010   APP INSTALL                 2-10                   2                 0
#
#       Criteo Revenue  Criteo Cost  Margin_criteo       date
# 134        19.527618    10.507066       9.020551 2019-10-16
# 135         0.056308     0.029815       0.026493 2019-10-11
# 136        23.707286    12.998124      10.709162 2019-10-12
# 137        23.070200    12.052886      11.017314 2019-10-27
# 138         0.001497     0.000125       0.001373 2019-10-23
# 139         0.179688     0.090608       0.089080 2019-10-23
# 140         0.000088     0.000010       0.000078 2019-10-25
# 141         0.000000     0.000000       0.000000 2019-10-08
# 142         0.000644     0.000030       0.000614 2019-10-12
# 143         0.123507     0.063849       0.059658 2019-10-26
# 144         0.000574     0.000000       0.000574 2019-10-21
# 145         0.000198     0.000110       0.000088 2019-10-14
# 146         0.000395     0.000100       0.000295 2019-10-17
# 147        40.502928    23.746097      16.756831 2019-10-11
# 148         0.540000     0.000000       0.540000 2019-11-22
# 149         0.000000     0.000000       0.000000 2019-11-24
# 150         0.007895     0.004342       0.003553 2019-10-29
# 151         0.000000     0.000000       0.000000 2019-10-08
# 152         0.064983     0.034511       0.030471 2019-10-15
# 153         9.835659     5.507208       4.328451 2019-10-28
# 154        18.990703     9.903099       9.087604 2019-10-24
# 155         0.000189     0.000924      -0.000734 2019-10-22
# 156        24.940652    13.732278      11.208374 2019-10-07
# 157        13.439538     7.494558       5.944979 2019-10-10
# 158        36.716147    21.704414      15.011733 2019-10-25
# 159         0.000000     0.000000       0.000000 2019-11-11
# 160         0.024710     0.013086       0.011624 2019-10-10
# 161        22.088615    11.557351      10.531264 2019-10-23
# 162         0.077416     0.038486       0.038931 2019-10-07
# 163         0.000755     0.000009       0.000746 2019-10-18
# ...              ...          ...            ...        ...
# 969         0.017826     0.009848       0.007978 2019-10-24
# 970         0.000000     0.000000       0.000000 2019-11-10
# 971        39.845674    23.350347      16.495327 2019-10-20
# 972        43.301814    26.931788      16.370026 2019-10-08
# 973         0.007446     0.004167       0.003278 2019-10-25
# 974        12.222346     7.379252       4.843094 2019-10-28
# 975         0.000165     0.000091       0.000074 2019-10-16
# 976         3.776339     1.255676       2.520662 2019-10-14
# 977        59.528236    35.740330      23.787906 2019-10-25
# 978         0.000000     0.000000       0.000000 2019-10-31
# 979        69.762363    42.593584      27.168779 2019-10-12
# 980         0.002060     0.001124       0.000936 2019-10-11
# 981         0.010315     0.005223       0.005092 2019-10-16
# 982         0.000000     0.000000       0.000000 2019-11-01
# 983         2.356276     1.433025       0.923252 2019-10-18
# 984         0.002428     0.001365       0.001063 2019-10-21
# 985         0.000073     0.000040       0.000033 2019-10-12
# 986         0.006950     0.002293       0.004657 2019-10-15
# 987         0.004179     0.002254       0.001925 2019-10-10
# 988         0.001517     0.000841       0.000676 2019-10-17
# 989         0.000131     0.000018       0.000113 2019-10-18
# 990         0.000000     0.000000       0.000000 2019-11-22
# 991         0.000943     0.000527       0.000416 2019-10-26
# 996         3.885667     2.421883       1.463784 2019-10-07
# 997        64.688011    40.523384      24.164628 2019-10-07
# 998         0.000000     0.000000       0.000000 2019-10-08
# 1007        3.303641     2.038052       1.265589 2019-10-12
# 1008        0.000636     0.000382       0.000254 2019-10-08
# 1009       50.539312    30.601978      19.937334 2019-10-26
# 1010        0.000000     0.000000       0.000000 2019-10-07
#
# [217 rows x 13 columns]

# %%
#We calculate the margin_criteo for the type compaign criteo APP_INSTALL 
APP_INSTALL ['Margin_criteo'].sum()
# Out:
# 1026.7478413068789

# %% [markdown]
# we calculate the total Margin criteo and we found 8828 (we get it from the df.describe ) and for this type compaign APP_INSTALL we get 1026 of the total 8828.

# %% [markdown]
# # Exploring Data 2 : matched_sales

# %% [markdown]
# #### matched_sales.tsv – Sales of an e-commerce website that are attributed to Criteo, using a post-click 30D attribution rule

# %%
#Read table
import pandas as pd
df1=pd.read_table(r'C:\Users\monjia\Downloads\matched_sales.tsv',sep='\t')

# %%
df1.head(10)
# Out:
#     Timestamp Environment       Os      Device  Campaign ID  \
# 0  1569889040         web  Windows     Desktop       113450
# 1  1569890180         web  Android  Smartphone       137914
# 2  1569890704         web  Windows     Desktop       137914
# 3  1569892066         web  Android  Smartphone       137914
# 4  1569892673         web  Windows     Desktop       137914
# 5  1569892689         web  Android  Smartphone       137914
# 6  1569892900         web   Mac OS     Desktop       137914
# 7  1569893490         web  Android  Smartphone       137914
# 8  1569893697         web  Android      Tablet       137914
# 9  1569893876         web  Android  Smartphone       137914
#
#                             User ID  Context ID  \
# 0  2EEEE2185BB347E07653128DDD7946B4           6
# 1  18F4B9C704A39843FE4354E1E2091942           8
# 2  513CD8C04005C7ED66F34CD98C63C455           9
# 3  1620E50E507DDF33489D80D7423111DF           7
# 4  85AC7958028EFF2231B4962D3611D2D3           6
# 5  8A5E21F9B4EF17BEA10016A36359B871           6
# 6  BF1BC289862CD559584BF33962A6C978           9
# 7  D505600BB8926FE75C10E4DC100A9B85           9
# 8  2C7F0DD62A7F9AD330A05BBEC0FBBE6F           9
# 9  45F39915EF95F5F798C50E9233DA1805           9
#
#                      Transaction ID  Order Value
# 0  687260E81F123BF7B22EB42E2CC740D9        32.08
# 1  4CA9C121F6F94CD135F4A6F4934D4843       149.92
# 2  F44BB650A3149704B9F86EF8796E6604       125.10
# 3  5E022540529ECBCB947C04D969260287        95.95
# 4  8428EF0717350A6C843B91957A30464B        83.54
# 5  F7B8F81C1F4AF903D80E3811561613F1        19.17
# 6  6584BC5B7DCE2FAC8AD7D79A91A31F08        28.12
# 7  8337F90049B963626B67E76820D8FF73       151.92
# 8  1AE05B4CD2233CF2C35EAFC93C8A8902        40.83
# 9  B21F9E882A575FA63F793AA12798E0C8        41.82

# %%
print('the shape of df1:',df1.shape)
print('the size of df1:',df1.size)
# Out:
# the shape of df1: (149809, 9)
# the size of df1: 1348281

# %%
df1.columns
# Out:
# Index(['Timestamp', 'Environment', 'Os', 'Device', 'Campaign ID', 'User ID',
#        'Context ID', 'Transaction ID', 'Order Value'],
#       dtype='object')

# %%
#print train data columns
print('Columns of the matched_sales dataset is', df1.columns)
# Out:
# Columns of the matched_sales dataset is Index(['Timestamp', 'Environment', 'Os', 'Device', 'Campaign ID', 'User ID',
#        'Context ID', 'Transaction ID', 'Order Value'],
#       dtype='object')

# %%
#Describe table
df1.describe()
# Out:
#           Timestamp    Campaign ID     Context ID    Order Value
# count  1.498090e+05  149809.000000  149809.000000  149808.000000
# mean   1.572520e+09  141789.036753       6.652591      76.258191
# std    1.430771e+06   20260.271847       2.274443     172.129753
# min    1.569889e+09  113450.000000       0.000000       0.000000
# 25%    1.571261e+09  137914.000000       6.000000      29.140000
# 50%    1.572638e+09  137914.000000       7.000000      48.770000
# 75%    1.573824e+09  137914.000000       8.000000      85.590000
# max    1.574674e+09  200094.000000      10.000000   51658.000000

# %%
#info table
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149809 entries, 0 to 149808
# Data columns (total 9 columns):
# Timestamp         149809 non-null int64
# Environment       149809 non-null object
# Os                149809 non-null object
# Device            149809 non-null object
# Campaign ID       149809 non-null int64
# User ID           149809 non-null object
# Context ID        149809 non-null int64
# Transaction ID    149786 non-null object
# Order Value       149808 non-null float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 10.3+ MB

# %%
#nan value
df1.isnull().sum()
# Out:
# Timestamp          0
# Environment        0
# Os                 0
# Device             0
# Campaign ID        0
# User ID            0
# Context ID         0
# Transaction ID    23
# Order Value        1
# dtype: int64

# %%
#Check nan valuer per column 
df1['Order Value'].unique()
# Out:
# array([  32.08,  149.92,  125.1 , ..., 1100.72,   93.78,     nan])

# %%
len(df1['Order Value'].unique())
# Out:
# 26904

# %%
#dropthe nan value 
df1['Order Value'].nunique()
# Out:
# 26903

# %%
#zero value 
zero_val = (df1 == 0.00).sum(axis=0)
zero_val
# Out:
# Timestamp             0
# Environment           0
# Os                    0
# Device                0
# Campaign ID           0
# User ID               0
# Context ID        10717
# Transaction ID        0
# Order Value        1668
# dtype: int64

# %% [markdown]
# ### 1.1. Use data visualization techniques to explore the dataset and identify data issue. Clean the dataset accordingly.
#
# ##### Tips: Transactions with an Order Value of zero should be removed; Transactions with abnormally high Order Value should be removed; Duplicated Transactions should be removed.

# %%
#We check the box plot order value 
fig,ax = plt.subplots()
df1.boxplot(column='Order Value')
plt.show()

# %%
#1/ Remove zero value 
df1.drop(df1[df1['Order Value']== 0 ].index, inplace = True ) 
#2/ transaction with abnormally value, to choose it i check 75% of order values and it's equal to 85.59 i get it from the descibe table 
#so for that i choose 85
df1.drop(df1[df1['Order Value'] > 85 ].index, inplace = True )

# %% [markdown]
# ###### When i plot the box plot before removing the order value greater than 86 i can't get a clear visualization  because there are a lot of outliers at the time I thought of eliminating these values using the mustache box (it comes down to eliminating the 3 rd quartile)
# ###### And know i re plot the graph after deleting the outliers values and here is the result

# %%
#fig = plt.figure(figsize=(8,6))
fig,ax = plt.subplots()
df1.boxplot(column='Order Value')
plt.show()

# %%
#to check that the zero value removed 
df1[df1['Order Value']== 0 ].count()
# Out:
# Timestamp         0
# Environment       0
# Os                0
# Device            0
# Campaign ID       0
# User ID           0
# Context ID        0
# Transaction ID    0
# Order Value       0
# dtype: int64

# %%
#We check duplicate Transaction id in the table 
df1.duplicated(subset=['Transaction ID']).value_counts()
# we have 143 duplicate transaction id
# Out:
# False    110280
# True        150
# dtype: int64

# %%
#to remove the duplicate value i kept the high value of order value 
df1 = df1.sort_values(by='Order Value', ascending=False)
df1 = df1.drop_duplicates(subset='Transaction ID', keep="first")

# %%
#To check that we delete the duplicate transaction id 
df1.duplicated(subset=['Transaction ID']).value_counts()
# Out:
# False    110280
# dtype: int64

# %% [markdown]
# ###### Here we have the User ID is the Cookie-centric identifier of the user (for each browser or device used there is a different user ID)
# ###### so we check for each device we need different user ID

# %%
Device=df1.groupby(['Device'])['User ID'].count()

# %%
Device
# Out:
# Device
# Desktop       58489
# Other             5
# Smartphone    35072
# Tablet        11925
# Unknown        4789
# Name: User ID, dtype: int64

# %% [markdown]
# Here for example for Desktop should the user have different user ID (58489 different id)

# %%
#we check that the user id be different
Device.duplicated()
# Out:
# Device
# Desktop       False
# Other         False
# Smartphone    False
# Tablet        False
# Unknown       False
# Name: User ID, dtype: bool

# %%
#Same idea that i put it for the device should we have different user id using os 
Os=df1.groupby(['Os'])['User ID'].count()

# %%
Os.duplicated()
# Out:
# Os
# Android    False
# Mac OS     False
# Other      False
# Unknown    False
# Windows    False
# iOS        False
# Name: User ID, dtype: bool

# %% [markdown]
# So here we checked that we have different user id

# %%
df1.shape
# Out:
# (110280, 9)

# %% [markdown]
# ### 1.2. Can you estimate the time zone of the client?

# %%
#to convert the timestamp into date 
df1 = df1.set_index(['Timestamp'])
df1.index = pd.to_datetime(df1.index, unit='s')

# %%
df1.head()
# Out:
#                     Environment       Os      Device  Campaign ID  \
# Timestamp
# 2019-10-12 16:12:46         web  Windows     Desktop       137914
# 2019-10-02 14:24:07         web  Windows     Desktop       137914
# 2019-10-31 06:56:08         web      iOS  Smartphone       137914
# 2019-11-03 21:49:36         web  Windows     Desktop       137914
# 2019-11-18 19:05:40         web  Android  Smartphone       137914
#
#                                               User ID  Context ID  \
# Timestamp
# 2019-10-12 16:12:46  B0E28FBAF7F6FB96321C2DECF944058C           6
# 2019-10-02 14:24:07  43BE93DCB6E54D266E71485DDE29EC32           8
# 2019-10-31 06:56:08  5485E7A857ED699F72618EC8B7D71867           6
# 2019-11-03 21:49:36  D15CB0B8488F4B0B9B3FCCD0E09B3229           8
# 2019-11-18 19:05:40  D3F6BADA8D110A0C13EB232D0C973C9B           6
#
#                                        Transaction ID  Order Value
# Timestamp
# 2019-10-12 16:12:46  1841ABF147D4623D93E10B665A3A2259         85.0
# 2019-10-02 14:24:07  06E0957A749C1B6B886DB3DB44C3FB9B         85.0
# 2019-10-31 06:56:08  C11D94D465FE5B204319FAC10ABF13A0         85.0
# 2019-11-03 21:49:36  D85348837218C66E0A081095D40056CF         85.0
# 2019-11-18 19:05:40  F4BCCF7C405A099717722BC275F435E2         85.0

# %%
df1.shape
# Out:
# (110280, 8)

# %% [markdown]
# ### 1.3. What is the evolution of the Criteo attributed revenue over time? Can you pinpoint and explain particular events during the period

# %% [markdown]
# ##### Here for the evolution of the criteo attributed revenue i choose to plot it over the day and week

# %%
#Resampe per day
Resample_per_day=df1['Order Value'].resample('d').sum()

# %%
Resample_per_day
# Out:
# Timestamp
# 2019-10-01     63156.60
# 2019-10-02     73615.05
# 2019-10-03     65497.07
# 2019-10-04     72726.27
# 2019-10-05     69024.29
# 2019-10-06     91084.52
# 2019-10-07     89267.04
# 2019-10-08     67498.88
# 2019-10-09     70863.00
# 2019-10-10     60277.65
# 2019-10-11     54976.92
# 2019-10-12     59816.62
# 2019-10-13     71497.08
# 2019-10-14     70788.08
# 2019-10-15     60482.68
# 2019-10-16     70096.95
# 2019-10-17     62690.79
# 2019-10-18     62671.81
# 2019-10-19     60527.80
# 2019-10-20     76671.65
# 2019-10-21     68379.19
# 2019-10-22     64780.12
# 2019-10-23     67899.43
# 2019-10-24     63461.79
# 2019-10-25     68638.14
# 2019-10-26     63718.03
# 2019-10-27     88417.88
# 2019-10-28     95633.61
# 2019-10-29     67814.57
# 2019-10-30     75530.49
# 2019-10-31     67530.79
# 2019-11-01     76511.10
# 2019-11-02     74062.07
# 2019-11-03     94039.30
# 2019-11-04     89243.62
# 2019-11-05     76208.83
# 2019-11-06     84832.88
# 2019-11-07     82610.26
# 2019-11-08     74750.08
# 2019-11-09     66768.37
# 2019-11-10     84335.37
# 2019-11-11    108963.43
# 2019-11-12     92775.56
# 2019-11-13     84161.62
# 2019-11-14     81085.21
# 2019-11-15     85888.03
# 2019-11-16     87127.50
# 2019-11-17    109493.32
# 2019-11-18     94575.35
# 2019-11-19     99513.10
# 2019-11-20    127085.59
# 2019-11-21    110799.13
# 2019-11-22    148239.77
# 2019-11-23    134703.87
# 2019-11-24    137025.12
# 2019-11-25     28400.16
# Freq: D, Name: Order Value, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
Resample_per_day.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("the evolution of the Criteo attributed revenue per day " , fontsize = 20)
ax.set_xlabel("day")
ax.set_ylabel("the sumOV")
ax.legend()
plt.show()

# %% [markdown]
# #### Here we plot the criteo revenu over the week

# %%
#Resample per week 
Resample_per_week=df1['Order Value'].resample('w').sum()

# %%
Resample_per_week
# Out:
# Timestamp
# 2019-10-06    435103.80
# 2019-10-13    474197.19
# 2019-10-20    463929.76
# 2019-10-27    485294.58
# 2019-11-03    551121.93
# 2019-11-10    558749.41
# 2019-11-17    649494.67
# 2019-11-24    851941.93
# 2019-12-01     28400.16
# Freq: W-SUN, Name: Order Value, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
Resample_per_week.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("the evolution of the Criteo attributed revenue per week " , fontsize = 20)
ax.set_xlabel("week")
ax.set_ylabel("the sumOV")
ax.legend()
plt.show()

# %% [markdown]
# For the two graphs that we plot per week or per day we show an augmentation of the sum of the order value We got a slight increase during the 5 weeks and then and then a pick for the 6th week (2019/11/24) end of year this from the chrismas

# %% [markdown]
# ### 1.4. Propose a vizualization for the evolution of the average OV per Os. Tips: Watch out for transactions with empty Transaction I

# %%
Groupby_average_OV=df1.groupby(['Os'])['Order Value'].mean()
Groupby_average_OV
# Out:
# Os
# Android    39.906754
# Mac OS     42.265046
# Other      39.018320
# Unknown    39.623243
# Windows    41.356928
# iOS        40.470485
# Name: Order Value, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
Groupby_average_OV.plot(kind='barh',color='orange')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("the evolution of the average OV per Os " , fontsize = 20)
ax.set_xlabel("OS")
ax.set_ylabel("the average OV")
ax.legend()
plt.show()

# %% [markdown]
# ##### The OS most used by users are mac OS first and windows in second positions. we notice that there is not a remarkable difference between all the beats

# %%
fig, ax = plt.subplots(figsize=(20, 10))

Groupby_average_OV.plot.pie(autopct='%.1f%%')
labels = [ "Android" , "Mac OS","other","unknown","Windows","IOS"]
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("the evolution of the average OV per Os " , fontsize = 20)
ax.legend(labels) 
plt.show()

# %% [markdown]
# ##### We also present the variation in order valueby OS in the form of pie plot.

# %%
#To check the empty rows in the column 'Transaction ID'
DF_new_row=df1.loc[df1['Transaction ID']=='']
DF_new_row.sum()
# Out:
# Environment       0.0
# Os                0.0
# Device            0.0
# Campaign ID       0.0
# User ID           0.0
# Context ID        0.0
# Transaction ID    0.0
# Order Value       0.0
# dtype: float64

# %% [markdown]
# ## Part 3

# %% [markdown]
# ### 3. Join the 2 datasets

# %%
df.columns
# Out:
# Index(['Day', 'Environment', 'Os', 'Campaign ID', 'Campaign Optimization',
#        'Campaign Type', 'Context IDs Eligible', 'Number of displays',
#        'Number of clicks', 'Criteo Revenue', 'Criteo Cost', 'Margin_criteo',
#        'date'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Environment', 'Os', 'Device', 'Campaign ID', 'User ID', 'Context ID',
#        'Transaction ID', 'Order Value'],
#       dtype='object')

# %%
# To join two table we need to the commun columns 
df2=pd.merge(df, df1)

# %%
df2.head()
# Out:
#           Day Environment       Os  Campaign ID Campaign Optimization  \
# 0  2019-10-16         web  Windows       194439    Visit Optimization
# 1  2019-10-16         web  Windows       194439    Visit Optimization
# 2  2019-10-16         web  Windows       194439    Visit Optimization
# 3  2019-10-16         web  Windows       194439    Visit Optimization
# 4  2019-10-16         web  Windows       194439    Visit Optimization
#
#        Campaign Type Context IDs Eligible  Number of displays  \
# 0  MID FUNNEL CUSTOM               0-6,10                   0
# 1  MID FUNNEL CUSTOM               0-6,10                   0
# 2  MID FUNNEL CUSTOM               0-6,10                   0
# 3  MID FUNNEL CUSTOM               0-6,10                   0
# 4  MID FUNNEL CUSTOM               0-6,10                   0
#
#    Number of clicks  Criteo Revenue  Criteo Cost  Margin_criteo       date  \
# 0                 0             0.0          0.0            0.0 2019-10-16
# 1                 0             0.0          0.0            0.0 2019-10-16
# 2                 0             0.0          0.0            0.0 2019-10-16
# 3                 0             0.0          0.0            0.0 2019-10-16
# 4                 0             0.0          0.0            0.0 2019-10-16
#
#     Device                           User ID  Context ID  \
# 0  Desktop  31CECB96B903887715CD98A2AE54ABB9           6
# 1  Desktop  95A304546B9A5B2C6B90B7F5D7A77E2B           6
# 2  Desktop  8829DBFA77742B6ACEE4DAD2C8D19E81           5
# 3  Desktop  BEE74C4B96722D757FB439BA3842702C           6
# 4  Desktop  E2C4A881E87B95CC33C9447A40C876D5           6
#
#                      Transaction ID  Order Value
# 0  A49A85736C899336F5891CB50ACE701D        81.63
# 1  CEE3A6089E38E2A5590990C91A7450AC        78.08
# 2  03445E68A6A527CC03D12E3464E3EFFF        77.13
# 3  E5142131ED34F261C9524AFBE147B911        74.58
# 4  D95153C02653910AFCE5FC2BF95F30B1        73.25

# %%
df2[df2['Campaign Type']=='LOWER FUNNEL CUSTOM']
# Out:
#                  Day Environment       Os  Campaign ID  \
# 44047     2019-12-13         web  Android       113450
# 44048     2019-12-13         web  Android       113450
# 44049     2019-12-13         web  Android       113450
# 44050     2019-12-13         web  Android       113450
# 44051     2019-12-13         web  Android       113450
# 44052     2019-12-13         web  Android       113450
# 44053     2019-12-13         web  Android       113450
# 44054     2019-12-13         web  Android       113450
# 44055     2019-12-13         web  Android       113450
# 44056     2019-12-13         web  Android       113450
# 44057     2019-12-13         web  Android       113450
# 44058     2019-12-13         web  Android       113450
# 44059     2019-12-13         web  Android       113450
# 44060     2019-12-13         web  Android       113450
# 44061     2019-12-13         web  Android       113450
# 44062     2019-12-13         web  Android       113450
# 44063     2019-12-13         web  Android       113450
# 44064     2019-12-13         web  Android       113450
# 44065     2019-12-13         web  Android       113450
# 44066     2019-12-13         web  Android       113450
# 44067     2019-12-13         web  Android       113450
# 44068     2019-12-13         web  Android       113450
# 44069     2019-12-13         web  Android       113450
# 44070     2019-12-13         web  Android       113450
# 44071     2019-12-13         web  Android       113450
# 44072     2019-12-13         web  Android       113450
# 44073     2019-12-13         web  Android       113450
# 44074     2019-12-13         web  Android       113450
# 44075     2019-12-13         web  Android       113450
# 44076     2019-12-13         web  Android       113450
# ...              ...         ...      ...          ...
# 12045571  2019-11-15         web      iOS       194906
# 12045572  2019-11-15         web      iOS       194906
# 12045573  2019-11-15         web      iOS       194906
# 12045574  2019-11-15         web      iOS       194906
# 12045575  2019-11-15         web      iOS       194906
# 12045576  2019-11-15         web      iOS       194906
# 12045577  2019-11-15         web      iOS       194906
# 12045578  2019-11-15         web      iOS       194906
# 12045579  2019-11-15         web      iOS       194906
# 12045580  2019-11-15         web      iOS       194906
# 12045581  2019-11-15         web      iOS       194906
# 12045582  2019-11-15         web      iOS       194906
# 12045583  2019-11-15         web      iOS       194906
# 12045584  2019-11-15         web      iOS       194906
# 12045585  2019-11-15         web      iOS       194906
# 12045586  2019-11-15         web      iOS       194906
# 12045587  2019-11-15         web      iOS       194906
# 12045588  2019-11-15         web      iOS       194906
# 12045589  2019-11-15         web      iOS       194906
# 12045590  2019-11-15         web      iOS       194906
# 12045591  2019-11-15         web      iOS       194906
# 12045592  2019-11-15         web      iOS       194906
# 12045593  2019-11-15         web      iOS       194906
# 12045594  2019-11-15         web      iOS       194906
# 12045595  2019-11-15         web      iOS       194906
# 12045596  2019-11-15         web      iOS       194906
# 12045597  2019-11-15         web      iOS       194906
# 12045598  2019-11-15         web      iOS       194906
# 12045599  2019-11-15         web      iOS       194906
# 12045600  2019-11-15         web      iOS       194906
#
#             Campaign Optimization        Campaign Type Context IDs Eligible  \
# 44047     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44048     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44049     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44050     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44051     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44052     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44053     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44054     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44055     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44056     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44057     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44058     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44059     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44060     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44061     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44062     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44063     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44064     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44065     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44066     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44067     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44068     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44069     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44070     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44071     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44072     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44073     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44074     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44075     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# 44076     Conversion Optimization  LOWER FUNNEL CUSTOM               2-6,10
# ...                           ...                  ...                  ...
# 12045571  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045572  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045573  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045574  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045575  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045576  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045577  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045578  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045579  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045580  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045581  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045582  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045583  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045584  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045585  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045586  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045587  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045588  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045589  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045590  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045591  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045592  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045593  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045594  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045595  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045596  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045597  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045598  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045599  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
# 12045600  Conversion Optimization  LOWER FUNNEL CUSTOM                 0-10
#
#           Number of displays  Number of clicks  Criteo Revenue  Criteo Cost  \
# 44047                 364710              3504       378.41518   206.126775
# 44048                 364710              3504       378.41518   206.126775
# 44049                 364710              3504       378.41518   206.126775
# 44050                 364710              3504       378.41518   206.126775
# 44051                 364710              3504       378.41518   206.126775
# 44052                 364710              3504       378.41518   206.126775
# 44053                 364710              3504       378.41518   206.126775
# 44054                 364710              3504       378.41518   206.126775
# 44055                 364710              3504       378.41518   206.126775
# 44056                 364710              3504       378.41518   206.126775
# 44057                 364710              3504       378.41518   206.126775
# 44058                 364710              3504       378.41518   206.126775
# 44059                 364710              3504       378.41518   206.126775
# 44060                 364710              3504       378.41518   206.126775
# 44061                 364710              3504       378.41518   206.126775
# 44062                 364710              3504       378.41518   206.126775
# 44063                 364710              3504       378.41518   206.126775
# 44064                 364710              3504       378.41518   206.126775
# 44065                 364710              3504       378.41518   206.126775
# 44066                 364710              3504       378.41518   206.126775
# 44067                 364710              3504       378.41518   206.126775
# 44068                 364710              3504       378.41518   206.126775
# 44069                 364710              3504       378.41518   206.126775
# 44070                 364710              3504       378.41518   206.126775
# 44071                 364710              3504       378.41518   206.126775
# 44072                 364710              3504       378.41518   206.126775
# 44073                 364710              3504       378.41518   206.126775
# 44074                 364710              3504       378.41518   206.126775
# 44075                 364710              3504       378.41518   206.126775
# 44076                 364710              3504       378.41518   206.126775
# ...                      ...               ...             ...          ...
# 12045571                   0                 0         0.00000     0.000000
# 12045572                   0                 0         0.00000     0.000000
# 12045573                   0                 0         0.00000     0.000000
# 12045574                   0                 0         0.00000     0.000000
# 12045575                   0                 0         0.00000     0.000000
# 12045576                   0                 0         0.00000     0.000000
# 12045577                   0                 0         0.00000     0.000000
# 12045578                   0                 0         0.00000     0.000000
# 12045579                   0                 0         0.00000     0.000000
# 12045580                   0                 0         0.00000     0.000000
# 12045581                   0                 0         0.00000     0.000000
# 12045582                   0                 0         0.00000     0.000000
# 12045583                   0                 0         0.00000     0.000000
# 12045584                   0                 0         0.00000     0.000000
# 12045585                   0                 0         0.00000     0.000000
# 12045586                   0                 0         0.00000     0.000000
# 12045587                   0                 0         0.00000     0.000000
# 12045588                   0                 0         0.00000     0.000000
# 12045589                   0                 0         0.00000     0.000000
# 12045590                   0                 0         0.00000     0.000000
# 12045591                   0                 0         0.00000     0.000000
# 12045592                   0                 0         0.00000     0.000000
# 12045593                   0                 0         0.00000     0.000000
# 12045594                   0                 0         0.00000     0.000000
# 12045595                   0                 0         0.00000     0.000000
# 12045596                   0                 0         0.00000     0.000000
# 12045597                   0                 0         0.00000     0.000000
# 12045598                   0                 0         0.00000     0.000000
# 12045599                   0                 0         0.00000     0.000000
# 12045600                   0                 0         0.00000     0.000000
#
#           Margin_criteo       date      Device  \
# 44047        172.288405 2019-12-13  Smartphone
# 44048        172.288405 2019-12-13  Smartphone
# 44049        172.288405 2019-12-13      Tablet
# 44050        172.288405 2019-12-13  Smartphone
# 44051        172.288405 2019-12-13  Smartphone
# 44052        172.288405 2019-12-13      Tablet
# 44053        172.288405 2019-12-13  Smartphone
# 44054        172.288405 2019-12-13  Smartphone
# 44055        172.288405 2019-12-13      Tablet
# 44056        172.288405 2019-12-13  Smartphone
# 44057        172.288405 2019-12-13  Smartphone
# 44058        172.288405 2019-12-13      Tablet
# 44059        172.288405 2019-12-13  Smartphone
# 44060        172.288405 2019-12-13  Smartphone
# 44061        172.288405 2019-12-13  Smartphone
# 44062        172.288405 2019-12-13  Smartphone
# 44063        172.288405 2019-12-13  Smartphone
# 44064        172.288405 2019-12-13  Smartphone
# 44065        172.288405 2019-12-13  Smartphone
# 44066        172.288405 2019-12-13  Smartphone
# 44067        172.288405 2019-12-13  Smartphone
# 44068        172.288405 2019-12-13  Smartphone
# 44069        172.288405 2019-12-13      Tablet
# 44070        172.288405 2019-12-13  Smartphone
# 44071        172.288405 2019-12-13  Smartphone
# 44072        172.288405 2019-12-13  Smartphone
# 44073        172.288405 2019-12-13  Smartphone
# 44074        172.288405 2019-12-13  Smartphone
# 44075        172.288405 2019-12-13      Tablet
# 44076        172.288405 2019-12-13  Smartphone
# ...                 ...        ...         ...
# 12045571       0.000000 2019-11-15  Smartphone
# 12045572       0.000000 2019-11-15  Smartphone
# 12045573       0.000000 2019-11-15      Tablet
# 12045574       0.000000 2019-11-15      Tablet
# 12045575       0.000000 2019-11-15  Smartphone
# 12045576       0.000000 2019-11-15      Tablet
# 12045577       0.000000 2019-11-15  Smartphone
# 12045578       0.000000 2019-11-15  Smartphone
# 12045579       0.000000 2019-11-15  Smartphone
# 12045580       0.000000 2019-11-15      Tablet
# 12045581       0.000000 2019-11-15  Smartphone
# 12045582       0.000000 2019-11-15      Tablet
# 12045583       0.000000 2019-11-15  Smartphone
# 12045584       0.000000 2019-11-15      Tablet
# 12045585       0.000000 2019-11-15      Tablet
# 12045586       0.000000 2019-11-15      Tablet
# 12045587       0.000000 2019-11-15      Tablet
# 12045588       0.000000 2019-11-15  Smartphone
# 12045589       0.000000 2019-11-15      Tablet
# 12045590       0.000000 2019-11-15      Tablet
# 12045591       0.000000 2019-11-15  Smartphone
# 12045592       0.000000 2019-11-15      Tablet
# 12045593       0.000000 2019-11-15  Smartphone
# 12045594       0.000000 2019-11-15  Smartphone
# 12045595       0.000000 2019-11-15      Tablet
# 12045596       0.000000 2019-11-15  Smartphone
# 12045597       0.000000 2019-11-15  Smartphone
# 12045598       0.000000 2019-11-15  Smartphone
# 12045599       0.000000 2019-11-15  Smartphone
# 12045600       0.000000 2019-11-15  Smartphone
#
#                                    User ID  Context ID  \
# 44047     07908F0FF5EE191C4F32B49DDBF5A2AE           5
# 44048     2D69CF8A86DEF5F8E1B829FA9D3760C8           5
# 44049     79436B8E204DD32E0708E1E15B21779C           6
# 44050     8473A1BFDB23E9358A2070B27D16A3B1           6
# 44051     2AF4BF1B44AF152750B8D6F193AC2FCD           6
# 44052     596E10EDC625C65B9985A0B3347DAFBF           6
# 44053     8F8A3E49FF783D979AC9E08A24A8F875           5
# 44054     4B7AC5E5CB1BFE0F5DCDE3007E47D46D           6
# 44055     4974CE7AE61688505AAD0EBE6CEFA804           6
# 44056     9A03662B894FF7049FA05DD83760438D           5
# 44057     A8C485CB0ECB546F094EA56A1E2AF333           0
# 44058     C440C11514CCC86EE561FEDC4614F47E           5
# 44059     0CA92568228DD19C982B19C25E168DDC           5
# 44060     711BB84084FECC266FA79B8B1205B984           6
# 44061     1F058350B6D85AE0F34D31C1C9541203           6
# 44062     5D88C7A3B330130B00FA1BC484DDBADF           0
# 44063     9421A247F05A93FFC56B7AA9E4DDE3CB           6
# 44064     8CD31D15A2E87FD64B4A91818FD11B99           0
# 44065     05A0CEC87EC7BAF0632D6FE684C36979           4
# 44066     362D57D14D5FC5002CB464AC7E20EBAA           5
# 44067     771E1BEA5FAC668FD9FDA866A8B94326           0
# 44068     FE314E0FAFFE1EC5C7705477D4A08979           6
# 44069     9A9980C78A074AA13D43F71116DB4886           4
# 44070     EC127D08DCC313827131F4B4B9C6A9FE           0
# 44071     441C7BBFCCC255E269E455BE688118F0           6
# 44072     1A468BB1DC3B341F7279312840039504           0
# 44073     51D7BDCA2E3AFC9A3CD734A3E03A6C6C           6
# 44074     D0764F42FE8D0183488616336091AD42           6
# 44075     3EC69044BD44B65449077CE3BD927345           6
# 44076     2E82934B7B3C6EA3C697618E70BE4AA0           0
# ...                                    ...         ...
# 12045571  5415E08E3FFF1C650EF729A570155B4A           6
# 12045572  AD0AF3E866E5E3E6471C688FDF779C31           9
# 12045573  641C1B3B6388F81553E2885FCD4B2BD1           9
# 12045574  7016FAE23544AA6394BECFE0DB3ACCE4           8
# 12045575  96C41CE470F805A1CBE7DC7FB6DBF14F           8
# 12045576  4E8C5F9E1F0CD7CA046EFD57234C6C8A           8
# 12045577  EECC6F8D1A31AECAE48D68D8A4B646B6           9
# 12045578  0DE6E13B1EB52FAF6C296A187F0E143B           9
# 12045579  A381EC47F0B502A3BA300BDB5E24B73F           9
# 12045580  0D71A87BB45E32B495E71ACE23981CB5           7
# 12045581  A9B489E07E10B073FFBE221BA9CB4E36           8
# 12045582  1BEC85F7961B062CC2A3FBAE5A086020           9
# 12045583  401B9AFE6DF4651CDC50DC96CFE90905           8
# 12045584  E56250F9F215165A810380C6CD60FF02           9
# 12045585  6A563784DD94EA192FD574F6A51C90D2           9
# 12045586  5F91A8E953670B3CE9206CAEDE98568E           9
# 12045587  44BF6F89C43953298892F77F86B0A479           9
# 12045588  E98CB4FC069AF77F912B19129603BF5B           8
# 12045589  C40DD9E604DEC4E8D1D3D873352D0166           7
# 12045590  DDD40C6045072A89422D64C016A30418           8
# 12045591  9B3208287EFC89D019B26EB32A0C9344           7
# 12045592  A18C0EAF6DCA590406F957180B62A2B7           8
# 12045593  9220068AC63A1603D232BB14FDD252EB           9
# 12045594  A02F07703454C0D46241EFA1C5F891E4           9
# 12045595  39A42DABDB051A541FA4F4B63E9AFA75           9
# 12045596  38B131571F704D0E5A6030C2C3F54307           9
# 12045597  38B131571F704D0E5A6030C2C3F54307           9
# 12045598  95F3F8A9AE29A233B0CDE2BC7CB75FF4           6
# 12045599  95F3F8A9AE29A233B0CDE2BC7CB75FF4           6
# 12045600  38B131571F704D0E5A6030C2C3F54307           9
#
#                             Transaction ID  Order Value
# 44047     63E34BBE214AECA46B440692CC09DD8B        85.00
# 44048     5900FBD5C82CE9692408BA8737A583A6        84.99
# 44049     6E79C40AC597BE44AE5696E6DE4AE5A0        84.99
# 44050     C9FAB2B0810F8857ACFF673CAA26471E        84.99
# 44051     F164C78D9CFCBD064E9F3FA613F70A08        84.98
# 44052     E79DCAB72EA556805E23478F328D09DE        84.93
# 44053     5E33696ADEE8CE023A6D8D83ED417D4B        84.92
# 44054     332BB0AAA4D9E6D221723BCD4923EDE1        84.92
# 44055     FF0B16476FA4B38BB9BFA1F8C49365E3        84.91
# 44056     0DF676CA41BC599DC387F260B7E800D3        84.80
# 44057     E09291AB3FAD4BC06D8F178542443A87        84.80
# 44058     6C44BA9131ECA0EBF34F8F014F0B2995        84.72
# 44059     C4E5445894C03E9DAB037223D5B43324        84.59
# 44060     F9C308CE546558A712F4B63D5E227B50        84.58
# 44061     203113E3DF4ACAD42BFE09B6FFDE3611        84.57
# 44062     DBA25DD8A614BBBB25DAFD8B348BF1DF        84.37
# 44063     AB742DBE3E450185A17D878587A24254        84.16
# 44064     D1EC8027EFA0A2F2B53D97DDD3C0A1D0        84.16
# 44065     E80E1FF644043D88876F5CB06351508E        84.14
# 44066     01166B792D3696B8871716FFACF721CB        84.12
# 44067     B0308387899F64F464AAC8BA4889BAE9        84.12
# 44068     E092A947B256BA63D03A75695BFCD7DE        84.03
# 44069     4903FBCD1F00F8F5AB11F6D237E2CC63        84.02
# 44070     40ECAA4149B13AFB1798D4D3EF149084        84.00
# 44071     5CA760FB16CDD01766B1D9F539CD9D18        83.99
# 44072     853863C07480B644177FC1C1108BD8A6        83.99
# 44073     A3A8B310FF0EAF1BEB49853CB5513443        83.99
# 44074     6A6A54EC9A832EB54E4FEFE936A2347B        83.99
# 44075     4C0A88F5804DF5AC6C417F0B62203257        83.92
# 44076     9F1115971EA1553ACA757F9D41A743CC        83.81
# ...                                    ...          ...
# 12045571  D0A07DC813C48BD844C396684AE61D4B        11.67
# 12045572  7924E53A6EFC6EF10A483B93AE3510B6        11.25
# 12045573  5ADFE50A656B3E449C35C8C0E5B703B5        11.24
# 12045574  C08D277E43B97EA2B349C64AF6595E7B        11.24
# 12045575  375C945C52A05A5523C372CE2634D00E        10.82
# 12045576  F194FA0643C2ED62271902A6644EE845        10.75
# 12045577  E136CEF334A12AFE11E6B6185646B67D        10.32
# 12045578  145E9FB6C735C79DFE344D7E24D84B9A        10.12
# 12045579  CFD434D3C04B2B6518EBCD2BB3893120        10.00
# 12045580  A3E03B53DB0DC94813F262689050D847         8.99
# 12045581  D765C0A76186C45B572F7E701EDBD066         8.99
# 12045582  5975E64920F17D8C1C8AA3FBE09DB9DE         8.99
# 12045583  EDFE8C0F6B3EDA56A5C059C90007EE43         8.33
# 12045584  B6CF61BDF3259AAC2C77C1E0FCE5F203         8.32
# 12045585  02C09367C6C694614DCEE3E4B9D1A3AD         8.29
# 12045586  E17F199905FF64DEB1D720D173AFB220         8.25
# 12045587  56AFD49515403DE58C17254004532E39         7.49
# 12045588  22F40E71D6839226A3CFE28D80B0C4CB         7.07
# 12045589  6DDBF93F73C594FED761C9B99389F542         6.58
# 12045590  5F105F35D7414066157734FEFF36212A         5.75
# 12045591  3534E7F0C68AD07EF09C6F9E63DE2C09         5.75
# 12045592  EF5AA7AC796A4029BD7BB23C7C3A8A7F         4.99
# 12045593  D0AAB83585ADE9666396B4CF73338729         4.50
# 12045594  B419BD38ACF215B5CA61FF5B49607C28         4.19
# 12045595  BCE3E1B279A859CBA7A2DA199C94A149         3.74
# 12045596  6702971998093D7E189486CF7F6496CD         3.38
# 12045597  460F5D296E7BBBA7B7FCE403D286CC62         2.92
# 12045598  E4CDEB29F4A00C24E6DCAF7497BD600E         2.49
# 12045599  81CC54FD306A93ACD9F8A5F85EC149D2         0.73
# 12045600  6997C8B7B21B14FB9A0B0E6090726948         0.21
#
# [11782366 rows x 18 columns]

# %% [markdown]
# #### Statistic tools

# %%
df2.shape
# Out:
# (12060681, 18)

# %%
df2.describe()
# Out:
#         Campaign ID  Number of displays  Number of clicks  Criteo Revenue  \
# count  1.136067e+07        1.136067e+07      1.136067e+07    1.136067e+07
# mean   1.381802e+05        1.695578e+06      8.634799e+03    3.323853e+03
# std    1.525379e+04        1.429901e+06      6.418731e+03    3.503857e+03
# min    1.134500e+05        0.000000e+00      0.000000e+00    0.000000e+00
# 25%    1.379140e+05        4.669170e+05      2.540000e+03    7.015284e+02
# 50%    1.379140e+05        1.328849e+06      7.492000e+03    2.025184e+03
# 75%    1.379140e+05        2.750505e+06      1.375000e+04    4.855827e+03
# max    2.000940e+05        6.413055e+06      3.485200e+04    1.805521e+04
#
#         Criteo Cost  Margin_criteo    Context ID   Order Value
# count  1.136067e+07   1.136067e+07  1.136067e+07  1.136056e+07
# mean   1.915434e+03   1.408419e+03  6.689171e+00  3.833750e+01
# std    2.059148e+03   1.448653e+03  2.275674e+00  1.782868e+01
# min    0.000000e+00  -7.538550e+01  0.000000e+00  2.000000e-02
# 25%    3.946768e+02   3.017487e+02  6.000000e+00  2.499000e+01
# 50%    1.127593e+03   9.149666e+02  7.000000e+00  3.631000e+01
# 75%    2.716917e+03   2.075248e+03  8.000000e+00  5.164000e+01
# max    1.058762e+04   7.467593e+03  1.000000e+01  7.600000e+01

# %% [markdown]
# ## Part 4

# %% [markdown]
# #### 4. Analyze Criteo Campaigns Performance from the advertiser’s perspective
#
# ##### 4.1. Identify the most performing (using performance and scale criteria) campaigns using a viz.

# %% [markdown]
# To identifie the most performing campaigns there are many methods
#
# #### Idea 1: we can plot the Margin Criteo per compaign Id
#
# #### Idea 2: we can plot the Order value per compaign Id
#
# #### Idea 3: We can check the number of clicks or displays for each compaign
#
# #### Idea 4: We can check the number of context ID if we have the compaigns contain more number (df2['Context ID']>6) then it will be the most performing
#
# (i choose >6 :
# because 7 The visitor has made one purchase (1 or several products bought)
#
# 8 The visitor has made 2 or 3 purchases (1 or several products bought per purchase)
#
# 9 The visitor has made 4 or more purchases (1 or several products bought per purchase))

# %%
#first idea
dg=df2.groupby(['Campaign ID'])['Margin_criteo'].sum()

# %%
dg
# Out:
# Campaign ID
# 113450    5.155450e+08
# 113890    2.156041e+07
# 137914    1.637404e+10
# 179971    9.338911e+06
# 181694    2.198270e+04
# 181696    1.485005e+04
# 182459    4.029755e+05
# 182460    7.297193e+05
# 194439    2.365378e+04
# 194905    1.023823e+07
# 194906    2.316891e+07
# 196137    3.807362e+04
# 196140    1.246386e+05
# 196251    2.041989e+07
# 198525    9.504636e+03
# 200094    9.001079e+06
# Name: Margin_criteo, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
dg.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("the Margin Criteo per compaign Id  " , fontsize = 20)
ax.set_xlabel("Campaign ID")
ax.set_ylabel("Margin_criteo")
plt.show()

# %%
methode_2=df2.groupby(['Campaign ID'])['Order Value'].sum()

# %%
methode_2
# Out:
# Campaign ID
# 113450    4.752088e+07
# 113890    9.845014e+06
# 137914    4.081528e+08
# 179971    3.326958e+06
# 181694    8.392262e+04
# 181696    6.590150e+04
# 182459    5.884344e+05
# 182460    1.159978e+06
# 194439    7.382039e+04
# 194905    4.815408e+06
# 194906    1.066331e+07
# 196137    6.227308e+04
# 196140    2.088360e+05
# 196251    3.940298e+06
# 198525    9.942250e+04
# 200094    1.502195e+06
# Name: Order Value, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
methode_2.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("the Margin Criteo per ov  " , fontsize = 20)
ax.set_xlabel("Campaign ID")
ax.set_ylabel("Order Value")
plt.show()

# %%
methode_3=df2.groupby(['Campaign ID'])['Number of clicks'].sum()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Add x-axis and y-axis
methode_3.plot(kind='bar')
ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("Cm id per clicks " , fontsize = 20)
ax.set_xlabel("Campaign ID")
ax.set_ylabel("Number of clicks")
plt.show()

# %% [markdown]
# For each method that we treated here we get the same compaign Id but we have problem to see the other compaign

# %% [markdown]
# #### 4.2. The previous viz made it challenging to see patterns. Can you adapt it? Which Criteo campaign types perform the best? Tips: use Campaign Type instead

# %%
campaign_types=df2.groupby(['Campaign Type'])['Margin_criteo'].sum()

# %%
campaign_types
# Out:
# Campaign Type
# APP INSTALL            3.683275e+04
# INAPP                  1.295407e+06
# LOWER FUNNEL CUSTOM    1.694455e+10
# MID FUNNEL CUSTOM      2.945413e+07
# PROSPECTING            9.338911e+06
# Name: Margin_criteo, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 10))

campaign_types.plot.pie(autopct='%.1f%%')
labels = [ "APP INSTALL " , "INAPP","LOWER FUNNEL CUSTOM","MID FUNNEL CUSTOM","PROSPECTING"]
#ax.grid(linestyle = '-.' , linewidth = 1 , color = '.5')
ax.set_title("campaign_types per margin " , fontsize = 20)
ax.legend(labels) 
plt.show()

# %% [markdown]
# The best compaign we get 99.8 percent for LOWER FUNNEL CUSTOM and 0.2 between the other
#
# i check it with hist plot and i get same result

# %% [markdown]
# ##### 4.3. Is the COS/ROAS a relevant metric to look at for all Criteo campaign types? What would you recommend looking at instead?

# %% [markdown]
# COS (Cost Of Sales):The ratio between the total cost of the campaign and the sales amount that the campaign generated. COS provides a good indication of your campaign’s ROI.
#
# COS = Revenue / Sales post-click

# %% [markdown]
# ROAS (Return On Advertising Spend):	Corresponds to the ratio between the Sales Amount the campaign generated and the total Cost of the campaign.
#
# ROAS = 1/COS

# %% [markdown]
# #### To check the COS/ROAS is a relevant metric we just show the ROAS = 1/COS

# %% [markdown]
# we calculate the Roas for each Criteo campaign type
#
# roas = sum(order value) / sum (criteo cost)

# %%
campaign_types=df2.groupby(['Campaign Type'])['Order Value'].sum()

# %%
campaign_cost=df2.groupby(['Campaign Type'])['Criteo Cost'].sum()

# %%
roas =campaign_types/campaign_cost

# %%
roas
# Out:
# Campaign Type
# APP INSTALL            2.834492
# INAPP                  1.057712
# LOWER FUNNEL CUSTOM    0.020868
# MID FUNNEL CUSTOM      0.158348
# PROSPECTING            0.206185
# dtype: float64

# %%
cos= 1/roas

# %%
cos
# Out:
# Campaign Type
# APP INSTALL             0.352797
# INAPP                   0.945437
# LOWER FUNNEL CUSTOM    47.919984
# MID FUNNEL CUSTOM       6.315216
# PROSPECTING             4.850022
# dtype: float64

# %% [markdown]
# ##### In this notebook i use different type plot bar,barh,box plot ,pie .. but i can't use the library seaborn so i use collab to plot some graphs
